# %% [markdown]
# <a href="https://colab.research.google.com/github/amritesh-21/amritesh18cse076/blob/main/Visualization_Lab_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path="https://raw.githubusercontent.com/Anasuya-Sahoo/DMDW-Lab/main/Toyota.csv"
data=pd.read_csv(path)
data.head()
# Out:
#    Unnamed: 0  Price   Age     KM  ... Automatic    CC  Doors  Weight
# 0           0  13500  23.0  46986  ...         0  2000  three    1165
# 1           1  13750  23.0  72937  ...         0  2000      3    1165
# 2           2  13950  24.0  41711  ...         0  2000      3    1165
# 3           3  14950  26.0  48000  ...         0  2000      3    1165
# 4           4  13750  30.0  38500  ...         0  2000      3    1170
#
# [5 rows x 11 columns]

# %%
data.dropna(axis=0,inplace=True)

# %%
data.shape
# Out:
# (1111, 11)

# %%
data.head()
# Out:
#    Unnamed: 0  Price   Age     KM  ... Automatic    CC  Doors  Weight
# 0           0  13500  23.0  46986  ...         0  2000  three    1165
# 1           1  13750  23.0  72937  ...         0  2000      3    1165
# 3           3  14950  26.0  48000  ...         0  2000      3    1165
# 4           4  13750  30.0  38500  ...         0  2000      3    1170
# 5           5  12950  32.0  61000  ...         0  2000      3    1170
#
# [5 rows x 11 columns]

# %%
sns.set(style="darkgrid")
sns.regplot(x=data['Age'],y=data['Price'])

# %%
sns.set(style="darkgrid")
sns.regplot(x=data['Age'],y=data['Price'],marker="*",fit_reg=False)

# %%
sns.displot(data['Age'])

# %%
sns.displot(data['Age'],kde=False)

# %%
sns.displot(data['Age'],kde=False,bins=5)

# %%
sns.countplot(x='FuelType',data=data)

# %%
sns.countplot(x='FuelType',data=data,hue="Automatic")

# %%
sns.boxplot(y=data['Price'])

# %%
sns.boxplot(x=data['FuelType'],y=data['Price'])

# %%
sns.pairplot(data,kind='countplot',hue='FuelType')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
